# %%
from predpatt import PredPatt, PredPattOpts
from predpatt import load_conllu

# %%
prevent_example = """
1	One	one	NUM	CD	NumType=Card	2	nummod	_	_
2	answer	answer	NOUN	NN	Number=Sing	3	nsubj	_	_
3	is	be	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
4	that	that	SCONJ	IN	_	7	mark	_	_
5	the	the	DET	DT	Definite=Def|PronType=Art	6	det	_	_
6	Pentagon	Pentagon	PROPN	NNP	Number=Sing	7	nsubj	_	_
7	prevented	prevent	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	3	ccomp	_	_
8	the	the	DET	DT	Definite=Def|PronType=Art	10	det	_	_
9	State	State	PROPN	NNP	Number=Sing	10	compound	_	_
10	Department	Department	PROPN	NNP	Number=Sing	7	dobj	_	_
11	from	from	SCONJ	IN	_	12	mark	_	_
12	running	run	VERB	VBG	VerbForm=Ger	7	advcl	_	_
13	the	the	DET	DT	Definite=Def|PronType=Art	14	det	_	_
14	CPA	CPA	PROPN	NNP	Number=Sing	12	dobj	_	SpaceAfter=No
15	.	.	PUNCT	.	_	3	punct	_	_
"""

delay_example = """
1	The	the	DET	DT	Definite=Def|PronType=Art	2	det	_	_
2	judge	judge	NOUN	NN	Number=Sing	4	nsubj	_	_
3	had	have	AUX	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	4	aux	_	_
4	agreed	agree	VERB	VBN	Tense=Past|VerbForm=Part	0	root	_	_
5	to	to	PART	TO	_	6	mark	_	_
6	delay	delay	VERB	VB	VerbForm=Inf	4	xcomp	_	_
7	the	the	DET	DT	Definite=Def|PronType=Art	10	det	_	_
8	civil	civil	ADJ	JJ	Degree=Pos	9	amod	_	_
9	rights	rights	NOUN	NNS	Number=Plur	10	compound	_	_
10	matter	matter	NOUN	NN	Number=Sing	6	dobj	_	_
11	from	from	ADP	IN	_	12	case	_	_
12	proceeding	proceeding	NOUN	NN	Number=Sing	6	nmod	_	_
13	until	until	ADP	IN	_	16	case	_	_
14	at	at	ADV	RB	_	15	case	_	_
15	least	least	ADV	RBS	Degree=Sup	16	nmod	_	_
16	October	October	PROPN	NNP	Number=Sing	6	nmod	_	_
17	2004	2004	NUM	CD	NumType=Card	16	nummod	_	SpaceAfter=No
18	.	.	PUNCT	.	_	4	punct	_	_
"""

discourage_example = """
1	Since	since	ADP	IN	_	2	case	_	_
2	reintroduction	reintroduction	NOUN	NN	Number=Sing	10	nmod	_	SpaceAfter=No
3	,	,	PUNCT	,	_	10	punct	_	_
4	however	however	ADV	RB	_	10	advmod	_	SpaceAfter=No
5	,	,	PUNCT	,	_	10	punct	_	_
6	Ripple	Ripple	PROPN	NNP	Number=Sing	10	nsubj	_	_
7	and	and	CONJ	CC	_	6	cc	_	_
8	Beschta	Beschta	PROPN	NNP	Number=Sing	6	conj	_	_
9	have	have	AUX	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	10	aux	_	_
10	found	find	VERB	VBN	Tense=Past|VerbForm=Part	0	root	_	SpaceAfter=No
11	,	,	PUNCT	,	_	10	punct	_	_
12	fear	fear	NOUN	NN	Number=Sing	18	nsubj	_	_
13	of	of	ADP	IN	_	15	case	_	_
14	the	the	DET	DT	Definite=Def|PronType=Art	15	det	_	_
15	wolves	wolf	NOUN	NNS	Number=Plur	12	nmod	_	_
16	apparently	apparently	ADV	RB	_	18	advmod	_	_
17	has	have	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	aux	_	_
18	discouraged	discourage	VERB	VBN	Tense=Past|VerbForm=Part	10	ccomp	_	_
19	the	the	DET	DT	Definite=Def|PronType=Art	20	det	_	_
20	elk	elk	NOUN	NNS	Number=Plur	18	dobj	_	_
21	from	from	SCONJ	IN	_	22	mark	_	_
22	spending	spend	VERB	VBG	VerbForm=Ger	18	advcl	_	_
23	too	too	ADV	RB	_	24	advmod	_	_
24	much	much	ADJ	JJ	Degree=Pos	25	amod	_	_
25	time	time	NOUN	NN	Number=Sing	22	dobj	_	_
26	at	at	ADP	IN	_	28	case	_	_
27	stream	stream	NOUN	NN	Number=Sing	28	compound	_	_
28	banks	bank	NOUN	NNS	Number=Plur	22	nmod	_	_
29	--	--	PUNCT	,	_	28	punct	_	_
30	where	where	ADV	WRB	PronType=Rel	33	advmod	_	_
31	they	they	PRON	PRP	Case=Nom|Number=Plur|Person=3|PronType=Prs	33	nsubj	_	_
32	are	be	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	33	cop	_	_
33	out	out	ADV	RB	_	28	acl:relcl	_	_
34	in	in	ADP	IN	_	36	case	_	_
35	the	the	DET	DT	Definite=Def|PronType=Art	36	det	_	_
36	open	open	ADJ	JJ	Degree=Pos	33	nmod	_	_
37	--	--	PUNCT	,	_	22	punct	_	_
38	and	and	CONJ	CC	_	22	cc	_	_
39	munching	munch	VERB	VBG	VerbForm=Ger	22	conj	_	_
40	on	on	ADP	IN	_	42	case	_	_
41	the	the	DET	DT	Definite=Def|PronType=Art	42	det	_	_
42	saplings	sapling	NOUN	NNS	Number=Plur	39	nmod	_	SpaceAfter=No
43	.	.	PUNCT	.	_	10	punct	_	_
"""

keeping_example = """
1	He	he	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs	3	nsubj	_	_
2	also	also	ADV	RB	_	3	advmod	_	_
3	ordered	order	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	0	root	_	_
4	that	that	SCONJ	IN	_	8	mark	_	_
5	the	the	DET	DT	Definite=Def|PronType=Art	6	det	_	_
6	receiver	receiver	NOUN	NN	Number=Sing	8	nsubj	_	_
7	not	not	ADV	RB	_	8	neg	_	_
8	get	get	VERB	VB	VerbForm=Inf	3	ccomp	_	_
9	a	a	DET	DT	Definite=Ind|PronType=Art	15	det	_	_
10	(	(	PUNCT	-LRB-	_	12	punct	_	SpaceAfter=No
11	I	I	PRON	PRP	Case=Nom|Number=Sing|Person=1|PronType=Prs	12	nsubj	_	_
12	think	think	VERB	VBP	Mood=Ind|Tense=Pres|VerbForm=Fin	15	parataxis	_	_
13	chrome	chrome	NOUN	NN	Number=Sing	12	dobj	_	SpaceAfter=No
14	)	)	PUNCT	-RRB-	_	12	punct	_	_
15	coating	coating	NOUN	NN	Number=Sing	8	dobj	_	_
16	that	that	DET	WDT	PronType=Rel	17	nsubj	_	_
17	helped	help	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	8	acl:relcl	_	_
18	keep	keep	VERB	VB	VerbForm=Inf	17	ccomp	_	_
19	the	the	DET	DT	Definite=Def|PronType=Art	20	det	_	_
20	gun	gun	NOUN	NN	Number=Sing	18	dobj	_	_
21	from	from	SCONJ	IN	_	22	mark	_	_
22	jamming	jam	VERB	VBG	VerbForm=Ger	18	advcl	_	SpaceAfter=No
23	.	.	PUNCT	.	_	3	punct	_	_
"""

benefit_example = """
1	It	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	2	expl	_	_
2	sounds	sound	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
3	like	like	SCONJ	IN	_	7	mark	_	_
4	your	you	PRON	PRP$	Person=2|Poss=Yes|PronType=Prs	5	nmod:poss	_	_
5	dog	dog	NOUN	NN	Number=Sing	7	nsubj	_	_
6	may	may	AUX	MD	VerbForm=Fin	7	aux	_	_
7	benefit	benefit	VERB	VB	VerbForm=Inf	2	advcl	_	_
8	from	from	SCONJ	IN	_	10	mark	_	_
9	being	be	AUX	VBG	VerbForm=Ger	10	auxpass	_	_
10	hospitalized	hospitalize	VERB	VBN	Tense=Past|VerbForm=Part|Voice=Pass	7	advcl	_	SpaceAfter=No
11	,	,	PUNCT	,	_	10	punct	_	_
12	and	and	CONJ	CC	_	10	cc	_	_
13	put	put	VERB	VBN	Tense=Past|VerbForm=Part	10	conj	_	_
14	on	on	ADP	IN	_	16	case	_	_
15	IV	iv	NOUN	NN	Number=Sing	16	compound	_	_
16	fluids	fluid	NOUN	NNS	Number=Plur	13	nmod	_	_
17	to	to	PART	TO	_	18	mark	_	_
18	help	help	VERB	VB	VerbForm=Inf	10	advcl	_	_
19	his	he	PRON	PRP$	Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs	20	nmod:poss	_	_
20	hydration	hydration	NOUN	NN	Number=Sing	18	dobj	_	SpaceAfter=No
21	,	,	PUNCT	,	_	18	punct	_	_
22	administer	administer	VERB	VB	VerbForm=Inf	18	conj	_	_
23	the	the	DET	DT	Definite=Def|PronType=Art	25	det	_	_
24	antibiotics	antibiotic	NOUN	NNS	Number=Plur	25	compound	_	_
25	IV	iv	NOUN	NN	Number=Sing	22	dobj	_	SpaceAfter=No
26	,	,	PUNCT	,	_	18	punct	_	_
27	and	and	CONJ	CC	_	18	cc	_	_
28	to	to	PART	TO	_	29	mark	_	_
29	ensure	ensure	VERB	VB	VerbForm=Inf	18	conj	_	_
30	that	that	SCONJ	IN	_	32	mark	_	_
31	he	he	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs	32	nsubj	_	_
32	starts	start	VERB	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	29	ccomp	_	_
33	to	to	PART	TO	_	34	mark	_	_
34	recover	recover	VERB	VB	VerbForm=Inf	32	xcomp	_	SpaceAfter=No
35	.	.	PUNCT	.	_	2	punct	_	_
"""

# examples = [prevent_example, delay_example, discourage_example, restrict_example, keeping_example]
# examples = [delay_example, restrict_example]
examples = [prevent_example, delay_example, discourage_example, keeping_example, benefit_example]
            #, benefit_example]

# %%
for i, ex in enumerate(examples):
    examples[i] = [ud_parse for sent_id, ud_parse in load_conllu(ex)][0]

# %%
resolve_relcl = True  # relative clauses
resolve_conj = False   # conjuction
borrow_arg_for_relcl = True


opts = PredPattOpts(
        resolve_relcl=resolve_relcl,
        borrow_arg_for_relcl=borrow_arg_for_relcl,
        resolve_conj=resolve_conj,
        cut=True
        
        )


for ex in examples:
    ppatt = PredPatt(ex, opts = opts)
    print(ppatt.instances)
    print(" ".join([token.text for token in ppatt.tokens]))
    print(ppatt.pprint(color=True))
# Out:
# [Predicate(is/2), Predicate(prevented/6), Predicate(running/11)]
# One answer is that the Pentagon prevented the State Department from running the CPA .
# 	?a is ?b
# 		?a: One answer
# 		?b: SOMETHING := the Pentagon prevented the State Department from running the CPA
# 	?a prevented ?b
# 		?a: the Pentagon
# 		?b: the State Department
# 	?a running ?b
# 		?a: the State Department
# 		?b: the CPA
# [Predicate(agreed/3), Predicate(delay/5)]
# The judge had agreed to delay the civil rights matter from proceeding until at least October 2004 .
# 	?a had agreed ?b
# 		?a: The judge
# 		?b: SOMETHING := to delay the civil rights matter from proceeding until at least October 2004
# 	?a delay ?b from ?c until ?d
# 		?a: The judge
# 		?b: the civil rights matter
# 		?c: proceeding
# 		?d: at least October 2004
# [Predicate(found/9), Predicate(discouraged/17), Predicate(spending/21), Predicate(out/32), Predicate(munching/38)]
# ...

# %% [markdown]
# PredPatt provides a straightforward way to show the predicate-argument content. You can enable/disable "`color`" and "`track_rule`" to generate the output that suits your needs.

# %% [markdown]
# In practice, iterating the extracted predicates is quite easy. Let's iteratively print out the predicate and its arguments.

# %%
print(" ".join([token.text for token in ppatt.tokens]))
for predicate in ppatt.instances:
    print("\t%s [%s-%s-%d]" % (" ".join(token.text for token in predicate.tokens),
                            predicate.root.text, predicate.root.gov_rel, predicate.root.position))
    for argument in predicate.arguments:
        print("\t\t%s [%s-%s-%d]" % (" ".join(token.text for token in argument.tokens),
                                     argument.root.text, argument.root.gov_rel, argument.root.position))

# %% [markdown]
# ### Configurable options
# PredPatt can be configured to tackle various syntactic phenomena. To do so, you can pass the configurable options to PredPatt.

# %%
from predpatt import PredPattOpts
from predpatt.util.ud import dep_v1, dep_v2
resolve_relcl = True  # relative clauses
resolve_appos = True  # appositional modifiers
resolve_amod = True   # adjectival modifiers
resolve_conj = True   # conjuction
resolve_poss = True   # possessives
ud = dep_v1.VERSION   # the version of UD
opts = PredPattOpts(
        resolve_relcl=resolve_relcl,
        resolve_appos=resolve_appos,
        resolve_amod=resolve_amod,
        resolve_conj=resolve_conj,
        resolve_poss=resolve_poss,
        ud=ud
        )

ppatt = PredPatt(concrete_example, opts=opts)
print " ".join([token.text for token in ppatt.tokens])
print ppatt.pprint(color=True)
# Out:
# Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# 	?a is/are 61 years old	[old-amod]
# 		?a: Pierre Vinken	[Vinken-nsubj]
# 	?a will join ?b as ?c ?d	[join-root]
# 		?a: Pierre Vinken , 61 years old	[Vinken-nsubj]
# 		?b: the board	[board-dobj]
# 		?c: a nonexecutive director	[director-nmod]
# 		?d: Nov. 29	[Nov.-nmod:tmod]
# 	?a is/are nonexecutive	[nonexecutive-amod]
# 		?a: a director	[director-nmod]
